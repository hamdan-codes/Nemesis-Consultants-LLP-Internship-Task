# %% [markdown]
# # Cleaning Data

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('dataframe.csv')
df
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 0           737265056   737265056       5000.0         5000.00
# 1           737265056   737265056       5000.0         5000.00
# 2           737265056   737265056       5000.0         5000.00
# 3           737265056   737265056       5000.0         5000.00
# 4           830329091   830329091       5000.0         5000.00
# ...               ...         ...          ...             ...
# 786358      732852505   732852505      50000.0        48904.96
# 786359      732852505   732852505      50000.0        48785.04
# 786360      732852505   732852505      50000.0        48766.15
# 786361      732852505   732852505      50000.0        48716.72
# 786362      732852505   732852505      50000.0        48666.83
#
#         transactionDateTime  transactionAmount         merchantName  \
# 0       2016-08-13T14:27:32              98.55                 Uber
# 1       2016-10-11T05:05:54              74.51          AMC #191138
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  int64
#  1   customerId                786363 non-null  int64
#  2   creditLimit               786363 non-null  float64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   merchantName              786363 non-null  object
#  7   acqCountry                781801 non-null  object
#  8   merchantCountryCode       785639 non-null  object
#  9   posEntryMode              782309 non-null  float64
#  10  posConditionCode          785954 non-null  float64
#  11  merchantCategoryCode      786363 non-null  object
#  12  currentExpDate            786363 non-null  object
# ...

# %%
df[df.isFraud == True]
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 694         984504651   984504651      50000.0         8613.80
# 971         114896048   114896048      15000.0        14113.96
# 1072        114896048   114896048      15000.0        13702.47
# 1113        114896048   114896048      15000.0         8943.58
# 1321        114896048   114896048      15000.0         5223.03
# ...               ...         ...          ...             ...
# 785680      207667444   207667444       7500.0         5517.88
# 785713      207667444   207667444       7500.0          764.48
# 785888      428856030   428856030        250.0           61.94
# 786054      657364505   657364505      20000.0        20000.00
# 786112      899818521   899818521       2500.0          340.38
#
#         transactionDateTime  transactionAmount              merchantName  \
# 694     2016-09-08T16:14:40             165.26         Walgreens #860120
# ...

# %%
# Dropping less required and repeated columns

df = df.drop(columns=[
    'echoBuffer', 'merchantCity', 'merchantState', 
    'merchantZip', 'posOnPremises', 'recurringAuthInd', 'merchantName'
])
df
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 0           737265056   737265056       5000.0         5000.00
# 1           737265056   737265056       5000.0         5000.00
# 2           737265056   737265056       5000.0         5000.00
# 3           737265056   737265056       5000.0         5000.00
# 4           830329091   830329091       5000.0         5000.00
# ...               ...         ...          ...             ...
# 786358      732852505   732852505      50000.0        48904.96
# 786359      732852505   732852505      50000.0        48785.04
# 786360      732852505   732852505      50000.0        48766.15
# 786361      732852505   732852505      50000.0        48716.72
# 786362      732852505   732852505      50000.0        48666.83
#
#         transactionDateTime  transactionAmount acqCountry merchantCountryCode  \
# 0       2016-08-13T14:27:32              98.55         US                  US
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  int64
#  1   customerId                786363 non-null  int64
#  2   creditLimit               786363 non-null  float64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   acqCountry                781801 non-null  object
#  7   merchantCountryCode       785639 non-null  object
#  8   posEntryMode              782309 non-null  float64
#  9   posConditionCode          785954 non-null  float64
#  10  merchantCategoryCode      786363 non-null  object
#  11  currentExpDate            786363 non-null  object
#  12  accountOpenDate           786363 non-null  object
# ...

# %%
# Dropping less required and repeated columns

df.drop(columns=[
    'customerId', 'transactionDateTime', 'merchantCountryCode', 
    'accountOpenDate', 'dateOfLastAddressChange', 'expirationDateKeyInMatch', 
    'cardLast4Digits', 'currentExpDate'
], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         accountNumber  creditLimit  availableMoney  transactionAmount  \
# 0           737265056       5000.0         5000.00              98.55
# 1           737265056       5000.0         5000.00              74.51
# 2           737265056       5000.0         5000.00               7.47
# 3           737265056       5000.0         5000.00               7.47
# 4           830329091       5000.0         5000.00              71.18
# ...               ...          ...             ...                ...
# 786358      732852505      50000.0        48904.96             119.92
# 786359      732852505      50000.0        48785.04              18.89
# 786360      732852505      50000.0        48766.15              49.43
# 786361      732852505      50000.0        48716.72              49.89
# 786362      732852505      50000.0        48666.83              72.18
#
#        acqCountry  posEntryMode  posConditionCode  merchantCategoryCode  \
# ...

# %%
df.columns
# Out:
# Index(['accountNumber', 'creditLimit', 'availableMoney', 'transactionAmount',
#        'acqCountry', 'posEntryMode', 'posConditionCode',
#        'merchantCategoryCode', 'cardCVV', 'enteredCVV', 'transactionType',
#        'currentBalance', 'cardPresent', 'isFraud'],
#       dtype='object')

# %%
df.corr() # Driving sme insights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5918cd08036> in <module>()
# ----> 1 df.corr() # Driving sme insights
#
# NameError: name 'df' is not defined

# %%
sns.heatmap(df.corr())

# %%
df.to_csv('CleanedData.csv', index=False) # Writing clean data to a csv file
